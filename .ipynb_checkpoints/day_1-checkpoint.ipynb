# %%
import pandas as pd

# %%
data=pd.read_csv('coffee_shop.csv')
data
# Out:
#          Date     Product  Quantity Sold  Price per Item  Total Sales  \
# 0  2025-01-01    Espresso             15            3.50         52.5
# 1  2025-01-01       Latte             22            4.00         88.0
# 2  2025-01-02  Cappuccino             18            3.75         67.5
# 3  2025-01-02   Americano             20            3.00         60.0
# 4  2025-01-03   Cold Brew             10            4.50         45.0
# 5  2025-01-03  Iced Latte             12            4.25         51.0
# 6  2025-01-04    Espresso             14            3.50         49.0
# 7  2025-01-04       Mocha             20            4.50         90.0
#
#   Customer Type
# 0       Regular
# 1           New
# 2       Regular
# 3           New
# 4       Regular
# 5           New
# 6       Regular
# 7           New

# %%
ndf=df.drop(columns=['Customer Type'])

# %%
ndf.head()
# Out:
#          Date     Product  Quantity Sold  Price per Item  Total Sales
# 0  2025-01-01    Espresso             15            3.50         52.5
# 1  2025-01-01       Latte             22            4.00         88.0
# 2  2025-01-02  Cappuccino             18            3.75         67.5
# 3  2025-01-02   Americano             20            3.00         60.0
# 4  2025-01-03   Cold Brew             10            4.50         45.0

# %%
df=pd.read_csv('test.csv')
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...
